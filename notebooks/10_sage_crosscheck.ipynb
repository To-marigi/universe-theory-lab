# %% [markdown]
# # SageMathによる厳密計算
#
# このノートは `scripts/sage.ps1 start` で起動した SageMath カーネルで実行します。

# %%
version()

# %%
R.<x> = PolynomialRing(QQ)
p = x^20 - 1
factor(p)

# %%
var('eta')
bool((cosh(eta)^2 - sinh(eta)^2).simplify_full() == 1)
